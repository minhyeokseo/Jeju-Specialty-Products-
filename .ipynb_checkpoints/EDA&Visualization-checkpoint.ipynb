# %% [markdown]
# # Import Library

# %%
import datetime

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.mixture import GaussianMixture

# %% [markdown]
# # Selling Data

# %%
selling=pd.read_csv('./data/selling.csv')
selling
# Out:
#                  id timestamp item co_op loc     supply    price        total
# 0     BC_A_J_201901   2019-01   BC     A   J 2433.60000 16.73000  40714.13000
# 1     BC_A_J_201902   2019-02   BC     A   J 1817.68000 15.04000  27337.91000
# 2     BC_A_J_201903   2019-03   BC     A   J 2082.54000 22.42000  46690.55000
# 3     BC_A_J_201904   2019-04   BC     A   J 1790.32000 38.66000  69213.77000
# 4     BC_A_J_201905   2019-05   BC     A   J  205.52000 23.57000   4844.11000
# ...             ...       ...  ...   ...  ..        ...      ...          ...
# 1984  TG_E_S_202211   2022-11   TG     E   S 7427.16000 10.95000  81327.40000
# 1985  TG_E_S_202212   2022-12   TG     E   S 7753.37000 15.77000 122270.64000
# 1986  TG_E_S_202301   2023-01   TG     E   S 8357.88000 19.25000 160889.19000
# 1987  TG_E_S_202302   2023-02   TG     E   S 6179.36000 22.53000 139220.98000
# 1988  TG_E_S_202303   2023-03   TG     E   S  601.74000 39.95000  24039.51000
#
# [1989 rows x 8 columns]

# %% [markdown]
# ## Some Basic Statistics

# %%
selling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1989 non-null   object
#  1   timestamp  1989 non-null   object
#  2   item       1989 non-null   object
#  3   co_op      1989 non-null   object
#  4   loc        1989 non-null   object
#  5   supply     1989 non-null   float64
#  6   price      1989 non-null   float64
#  7   total      1989 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 124.4+ KB

# %%
selling.describe()
# Out:
#             supply      price        total
# count   1989.00000 1989.00000   1989.00000
# mean    3552.03174   11.43386  32464.44540
# std    13615.48507   16.37413  78808.40596
# min        0.00000    0.00000      0.00000
# 25%        0.00000    0.00000      0.00000
# 50%      155.44000    3.15000   1731.18000
# 75%     1817.68000   17.18000  24285.24000
# max   231639.20000   91.65000 881089.20000

# %%
selling.corr(numeric_only=True)
# Out:
#          supply    price   total
# supply  1.00000 -0.03657 0.77699
# price  -0.03657  1.00000 0.15018
# total   0.77699  0.15018 1.00000

# %% [markdown]
# ## Draw Boxplot & Lineplot about 'supply' & 'price' column

# %%
fig = plt.figure(figsize=(20, 8))
sns.boxplot(data=selling,
            x = "item",
            y = "supply")
plt.ylabel('supply (100kg)')
plt.show() # 특이사항 없음

# %%
fig = plt.figure(figsize=(20, 8))
sns.lineplot(data=selling,
             x='timestamp',
             y='supply',
             hue='item',
            ci=None)
plt.xticks(rotation=45)
plt.ylabel('supply (100kg)')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\3083799093.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=selling,

# %%
fig = plt.figure(figsize=(20, 8))
sns.boxplot(data=selling,
            x = "item",
            y = "price")
plt.ylabel('price')
plt.show() # 감귤(TG) 혼자 상이한 분포를 가진 모습

# %%
fig = plt.figure(figsize=(20, 8))
sns.lineplot(data=selling,
             x='timestamp',
             y='price',
             hue='item',
             ci=None)
plt.xticks(rotation=45)
plt.ylabel('price (100won)')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\3870929051.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=selling,

# %%
se=selling.copy()
for idx in range(len(se)):
    se.loc[idx,'timestamp']=se.loc[idx,'timestamp'][:4]
se.groupby('timestamp',as_index=False)['price'].mean()
# Out:
#   timestamp    price
# 0      2019 10.43628
# 1      2020 11.18776
# 2      2021 11.22669
# 3      2022 12.36312
# 4      2023 13.52017

# %%
fig = plt.figure(figsize=(20, 8))
sns.lineplot(data=se,
             x='timestamp',
             y='price',
             ci=None)
plt.xticks(rotation=45)
plt.ylabel('price (100won)')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\465729282.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=se,

# %% [markdown]
# ## Draw Histplot about Each Items

# %%
df=selling[(selling['item']=='BC')&(selling['price']>0)].reset_index(drop=True)
sns.histplot(data=df,
             x='price',
             binwidth=2
            )
plt.xticks(rotation=45)
plt.show()

# %%
df=selling[(selling['item']=='CB')&(selling['price']>0)].reset_index(drop=True)
sns.histplot(data=df,
             x='price',
             binwidth=2
            )
plt.xticks(rotation=45)
plt.show()

# %%
df=selling[(selling['item']=='RD')&(selling['price']>0)].reset_index(drop=True)
sns.histplot(data=df,
             x='price',
             binwidth=2
            )
plt.xticks(rotation=45)
plt.show()

# %%
df=selling[(selling['item']=='CR')&(selling['price']>0)].reset_index(drop=True)
sns.histplot(data=df,
             x='price',
             binwidth=2
            )
plt.xticks(rotation=45)
plt.show()

# %%
df=selling[(selling['item']=='TG')&(selling['price']>0)].reset_index(drop=True)
sns.histplot(data=df,
             x='price',
             binwidth=2
            )
plt.xticks(rotation=45)
plt.show() # 두 개의 가우시안 분포가 혼합되어 있는 모습 발견

# %% [markdown]
# ## Devide TG with Gaussian Mixture Model

# %%
# GMM 모델 사용을 위해 이상치 파악 -> 없음
df=selling[(selling['item']=='TG')&(selling['price']>0)].reset_index(drop=True)
sns.boxplot(data=df,
            x = "item",
            y = "price")
# Out:
# <Axes: xlabel='item', ylabel='price'>

# %% [markdown]
# ### Fit and Predict

# %%
tg_df=selling[(selling['item']=='TG')&(selling['price']>0)]
tg_dff=tg_df[['price']]
gmm = GaussianMixture(n_components=2, random_state=42, n_init=10, max_iter=300).fit(tg_dff)
gmm_cluster_labels = gmm.predict(tg_dff)
tg_df['expen'] = gmm_cluster_labels
tg_df['expen'] = np.where(tg_df['expen'] == 1, 'expensive', 'cheap')
tg_df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\84815963.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tg_df['expen'] = gmm_cluster_labels
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\84815963.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tg_df['expen'] = np.where(tg_df['expen'] == 1, 'expensive', 'cheap')
#                  id timestamp item co_op loc     supply    price        total
# 1479  TG_A_J_201901   2019-01   TG     A   J 7151.48000 15.14000 108273.41000  \
# 1480  TG_A_J_201902   2019-02   TG     A   J 1448.29000 17.59000  25475.42000
# 1481  TG_A_J_201903   2019-03   TG     A   J  571.36000 33.66000  19231.98000
# 1482  TG_A_J_201904   2019-04   TG     A   J   66.67000 15.92000   1061.39000
# 1483  TG_A_J_201905   2019-05   TG     A   J   70.94000 16.50000   1170.51000
# ...             ...       ...  ...   ...  ..        ...      ...          ...
# 1984  TG_E_S_202211   2022-11   TG     E   S 7427.16000 10.95000  81327.40000
# 1985  TG_E_S_202212   2022-12   TG     E   S 7753.37000 15.77000 122270.64000
# 1986  TG_E_S_202301   2023-01   TG     E   S 8357.88000 19.25000 160889.19000
# 1987  TG_E_S_202302   2023-02   TG     E   S 6179.36000 22.53000 139220.98000
# 1988  TG_E_S_202303   2023-03   TG     E   S  601.74000 39.95000  24039.51000
#
#           expen
# 1479      cheap
# 1480      cheap
# 1481  expensive
# 1482      cheap
# 1483      cheap
# ...         ...
# 1984      cheap
# 1985      cheap
# 1986      cheap
# 1987      cheap
# 1988  expensive
#
# [509 rows x 9 columns]

# %% [markdown]
# ### Scatterplot & Histplot

# %%
sns.scatterplot(data=tg_df,
                x='timestamp',
                y='price',
                hue='expen'
            )
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize=(20, 8))
sns.histplot(data=tg_df,
             x='timestamp',
             hue='expen'
            )

plt.xticks(rotation=45)
plt.show()

# %%
# 주기 파악이 되었으니 달 정보만 추출
tg_df['month']=0
for idx in range(len(tg_df)):
    tg_df.iloc[idx,-1]=int(tg_df.iloc[idx,1][-2:])
tg_df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1072\3570173736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tg_df['month']=0
#                  id timestamp item co_op loc     supply    price        total
# 1479  TG_A_J_201901   2019-01   TG     A   J 7151.48000 15.14000 108273.41000  \
# 1480  TG_A_J_201902   2019-02   TG     A   J 1448.29000 17.59000  25475.42000
# 1481  TG_A_J_201903   2019-03   TG     A   J  571.36000 33.66000  19231.98000
# 1482  TG_A_J_201904   2019-04   TG     A   J   66.67000 15.92000   1061.39000
# 1483  TG_A_J_201905   2019-05   TG     A   J   70.94000 16.50000   1170.51000
# ...             ...       ...  ...   ...  ..        ...      ...          ...
# 1984  TG_E_S_202211   2022-11   TG     E   S 7427.16000 10.95000  81327.40000
# 1985  TG_E_S_202212   2022-12   TG     E   S 7753.37000 15.77000 122270.64000
# 1986  TG_E_S_202301   2023-01   TG     E   S 8357.88000 19.25000 160889.19000
# 1987  TG_E_S_202302   2023-02   TG     E   S 6179.36000 22.53000 139220.98000
# 1988  TG_E_S_202303   2023-03   TG     E   S  601.74000 39.95000  24039.51000
#
#           expen  month
# 1479      cheap      1
# 1480      cheap      2
# 1481  expensive      3
# 1482      cheap      4
# 1483      cheap      5
# ...         ...    ...
# 1984      cheap     11
# 1985      cheap     12
# 1986      cheap      1
# 1987      cheap      2
# 1988  expensive      3
#
# [509 rows x 10 columns]

# %%
fig = plt.figure(figsize=(20, 8))
sns.histplot(data=tg_df,
             x='month',
             hue='expen',
            binrange=(0.5,12.5),
            binwidth=1
            )

plt.show()

# 3월부터 9월까지는 비싼 감귤 (만감류&하우스)
# 10월부터 2월까지는 싼 감귤 (노지) 이 주로 판매됨

# %% [markdown]
# ### TG -> C(heap)TG/E(xpensive)TG in Selling Table

# %%
for idx in range(len(tg_df)):
    if tg_df.iloc[idx,-2]=='expensive':
        tg_df.iloc[idx,2]='ETG'
    else:
        tg_df.iloc[idx,2]='CTG'
tg_df
# Out:
#                  id timestamp item co_op loc     supply    price        total
# 1479  TG_A_J_201901   2019-01  CTG     A   J 7151.48000 15.14000 108273.41000  \
# 1480  TG_A_J_201902   2019-02  CTG     A   J 1448.29000 17.59000  25475.42000
# 1481  TG_A_J_201903   2019-03  ETG     A   J  571.36000 33.66000  19231.98000
# 1482  TG_A_J_201904   2019-04  CTG     A   J   66.67000 15.92000   1061.39000
# 1483  TG_A_J_201905   2019-05  CTG     A   J   70.94000 16.50000   1170.51000
# ...             ...       ...  ...   ...  ..        ...      ...          ...
# 1984  TG_E_S_202211   2022-11  CTG     E   S 7427.16000 10.95000  81327.40000
# 1985  TG_E_S_202212   2022-12  CTG     E   S 7753.37000 15.77000 122270.64000
# 1986  TG_E_S_202301   2023-01  CTG     E   S 8357.88000 19.25000 160889.19000
# 1987  TG_E_S_202302   2023-02  CTG     E   S 6179.36000 22.53000 139220.98000
# 1988  TG_E_S_202303   2023-03  ETG     E   S  601.74000 39.95000  24039.51000
#
#           expen  month
# 1479      cheap      1
# 1480      cheap      2
# 1481  expensive      3
# 1482      cheap      4
# 1483      cheap      5
# ...         ...    ...
# 1984      cheap     11
# 1985      cheap     12
# 1986      cheap      1
# 1987      cheap      2
# 1988  expensive      3
#
# [509 rows x 10 columns]

# %%
for idx in tg_df.index:
    selling.loc[idx,'item']=tg_df.loc[idx,'item']
selling
# Out:
#                  id timestamp item co_op loc     supply    price        total
# 0     BC_A_J_201901   2019-01   BC     A   J 2433.60000 16.73000  40714.13000
# 1     BC_A_J_201902   2019-02   BC     A   J 1817.68000 15.04000  27337.91000
# 2     BC_A_J_201903   2019-03   BC     A   J 2082.54000 22.42000  46690.55000
# 3     BC_A_J_201904   2019-04   BC     A   J 1790.32000 38.66000  69213.77000
# 4     BC_A_J_201905   2019-05   BC     A   J  205.52000 23.57000   4844.11000
# ...             ...       ...  ...   ...  ..        ...      ...          ...
# 1984  TG_E_S_202211   2022-11  CTG     E   S 7427.16000 10.95000  81327.40000
# 1985  TG_E_S_202212   2022-12  CTG     E   S 7753.37000 15.77000 122270.64000
# 1986  TG_E_S_202301   2023-01  CTG     E   S 8357.88000 19.25000 160889.19000
# 1987  TG_E_S_202302   2023-02  CTG     E   S 6179.36000 22.53000 139220.98000
# 1988  TG_E_S_202303   2023-03  ETG     E   S  601.74000 39.95000  24039.51000
#
# [1989 rows x 8 columns]

# %%
브로콜리 5개월

당근 3~4개월

양배추 5개월

무 4개월

감귤 - 노지 3월~10월초 수확: 11월~2월
	만감 6월~1월 수확: 2월~5월
	하우스 10월~3월 수확 4월~9월

# %% [markdown]
# # trade

# %%
trade=pd.read_csv('./data/preprocessed_trade.csv')
trade
# Out:
#      timestamp item  expo_quantity  expo_rev  impo_quantity  impo_cost  margin
# 0      2019-01   TM         356571       990              0          0     990
# 1      2019-01   ON         821330       222        4003206       1118    -896
# 2      2019-01   SL             60         1          93405        128    -127
# 3      2019-01   BC            160         1         638913        563    -562
# 4      2019-01   BS              0         0           7580         38     -38
# ...        ...  ...            ...       ...            ...        ...     ...
# 1269   2023-02   PP              0         0          23830         71     -71
# 1270   2023-02   AP         135165       351              0          0     351
# 1271   2023-02   PR        2206012      5411              1          0    5411
# 1272   2023-02   CE              5         0              0          0       0
# 1273   2023-02   PU              0         0              2          0       0
#
# [1274 rows x 7 columns]

# %%
selling['item'].unique()
# Out:
# array(['BC', 'CB', 'CR', 'RD', 'TG'], dtype=object)

# %%
bc_sell=selling[selling['item']=='BC'].reset_index(drop=True)
bc_sell
# Out:
#                 id timestamp item co_op loc     supply    price       total
# 0    BC_A_J_201901   2019-01   BC     A   J 2433.60000 16.73000 40714.13000
# 1    BC_A_J_201902   2019-02   BC     A   J 1817.68000 15.04000 27337.91000
# 2    BC_A_J_201903   2019-03   BC     A   J 2082.54000 22.42000 46690.55000
# 3    BC_A_J_201904   2019-04   BC     A   J 1790.32000 38.66000 69213.77000
# 4    BC_A_J_201905   2019-05   BC     A   J  205.52000 23.57000  4844.11000
# ..             ...       ...  ...   ...  ..        ...      ...         ...
# 454  BC_E_S_202211   2022-11   BC     E   S  109.84000 12.04000  1322.47000
# 455  BC_E_S_202212   2022-12   BC     E   S  206.00000 18.27000  3763.62000
# 456  BC_E_S_202301   2023-01   BC     E   S  346.08000 16.43000  5686.09000
# 457  BC_E_S_202302   2023-02   BC     E   S  547.68000 20.76000 11369.84000
# 458  BC_E_S_202303   2023-03   BC     E   S   46.48000 33.59000  1561.26000
#
# [459 rows x 8 columns]

# %%
tra=trade[trade['item']!='BC'].reset_index(drop=True)
tra
# Out:
#      timestamp item  expo_quantity  expo_rev  impo_quantity  impo_cost  margin
# 0      2019-01   TM         356571       990              0          0     990
# 1      2019-01   ON         821330       222        4003206       1118    -896
# 2      2019-01   SL             60         1          93405        128    -127
# 3      2019-01   BS              0         0           7580         38     -38
# 4      2019-01   CB         184650        94         395802         90       4
# ...        ...  ...            ...       ...            ...        ...     ...
# 1219   2023-02   PP              0         0          23830         71     -71
# 1220   2023-02   AP         135165       351              0          0     351
# 1221   2023-02   PR        2206012      5411              1          0    5411
# 1222   2023-02   CE              5         0              0          0       0
# 1223   2023-02   PU              0         0              2          0       0
#
# [1224 rows x 7 columns]

# %%
bc_tra=pd.merge(bc_sell,tra,on='timestamp')
bc_tra
# Out:
#                   id timestamp item_x co_op loc     supply    price
# 0      BC_A_J_201901   2019-01     BC     A   J 2433.60000 16.73000  \
# 1      BC_A_J_201901   2019-01     BC     A   J 2433.60000 16.73000
# 2      BC_A_J_201901   2019-01     BC     A   J 2433.60000 16.73000
# 3      BC_A_J_201901   2019-01     BC     A   J 2433.60000 16.73000
# 4      BC_A_J_201901   2019-01     BC     A   J 2433.60000 16.73000
# ...              ...       ...    ...   ...  ..        ...      ...
# 11011  BC_E_S_202302   2023-02     BC     E   S  547.68000 20.76000
# 11012  BC_E_S_202302   2023-02     BC     E   S  547.68000 20.76000
# 11013  BC_E_S_202302   2023-02     BC     E   S  547.68000 20.76000
# 11014  BC_E_S_202302   2023-02     BC     E   S  547.68000 20.76000
# 11015  BC_E_S_202302   2023-02     BC     E   S  547.68000 20.76000
#
#             total item_y  expo_quantity  expo_rev  impo_quantity  impo_cost
# 0     40714.13000     TM         356571       990              0          0  \
# 1     40714.13000     ON         821330       222        4003206       1118
# 2     40714.13000     SL             60         1          93405        128
# 3     40714.13000     BS              0         0           7580         38
# 4     40714.13000     CB         184650        94         395802         90
# ...           ...    ...            ...       ...            ...        ...
# 11011 11369.84000     PP              0         0          23830         71
# 11012 11369.84000     AP         135165       351              0          0
# 11013 11369.84000     PR        2206012      5411              1          0
# 11014 11369.84000     CE              5         0              0          0
# 11015 11369.84000     PU              0         0              2          0
#
#        margin
# 0         990
# 1        -896
# 2        -127
# 3         -38
# 4           4
# ...       ...
# 11011     -71
# 11012     351
# 11013    5411
# 11014       0
# 11015       0
#
# [11016 rows x 14 columns]

# %%
fig = plt.figure(figsize=(25, 12))
sns.lineplot(data=tra,
             x='timestamp',
             y='impo_quantity',
             hue='item')
plt.xticks(rotation=45)
# plt.ylabel('total (')
plt.show()
